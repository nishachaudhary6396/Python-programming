# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('image.jpg')
img
# Out:
# array([[[ 41,  10,  16],
#         [ 41,  10,  16],
#         [ 41,  10,  16],
#         ...,
#         [198, 207, 224],
#         [183, 195, 209],
#         [172, 184, 198]],
#
#        [[ 41,  10,  16],
#         [ 41,  10,  16],
#         [ 41,  10,  16],
#         ...,
#         [189, 198, 213],
#         [173, 185, 199],
#         [160, 172, 186]],
#
#        [[ 41,  10,  16],
#         [ 41,  10,  16],
#         [ 41,  10,  16],
#         ...,
#         [174, 181, 197],
#         [156, 165, 180],
#         [141, 150, 165]],
#
#        ...,
#
#        [[143, 141, 152],
#         [144, 142, 153],
#         [145, 143, 154],
#         ...,
#         [192, 193, 195],
#         [192, 193, 195],
#         [192, 193, 195]],
#
#        [[142, 140, 151],
#         [142, 140, 151],
#         [143, 141, 152],
#         ...,
#         [191, 192, 194],
#         [190, 191, 193],
#         [190, 191, 193]],
#
#        [[141, 139, 150],
#         [141, 139, 150],
#         [142, 140, 151],
#         ...,
#         [189, 190, 192],
#         [189, 190, 192],
#         [189, 190, 192]]], shape=(183, 275, 3), dtype=uint8)

# %%
plt.imshow(img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(274.5), np.float64(182.5), np.float64(-0.5))

# %%
cropped_img = img[50:200, 100:400]
plt.imshow(cropped_img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(174.5), np.float64(132.5), np.float64(-0.5))
