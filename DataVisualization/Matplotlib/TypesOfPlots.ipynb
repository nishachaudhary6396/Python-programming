# %%
#Types of pLOTS
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0,5,11)
y = x**2

plt.scatter(x,y)

# %%
from random import sample
data = sample(range(1,1000),100)
plt.hist(data)
# Out:
# (array([14., 11.,  9., 10., 10., 10.,  7., 13., 11.,  5.]),
#  array([  7. , 105.6, 204.2, 302.8, 401.4, 500. , 598.6, 697.2, 795.8,
#         894.4, 993. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x166dd3d9400>,
#   <matplotlib.lines.Line2D at 0x166dd3d9550>],
#  'caps': [<matplotlib.lines.Line2D at 0x166dd3d96a0>,
#   <matplotlib.lines.Line2D at 0x166dd3d97f0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x166dd3d92b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x166dd3d9940>],
#  'fliers': [<matplotlib.lines.Line2D at 0x166dd3d9a90>],
#  'means': []}
