# %% [markdown]
# # Data Science Task
# ## Section1: Data Understanding and preprocessing

# %% [markdown]
# Q1. Data Loading & Inspection
# Load the dataset using pandas in a Jupyter cell.
#
#
# -Display first 5 rows.
# -What is the shape of the dataset?
# -List all columns and their data types.
# -Identify missing values.

# %%
#Section 1 -> Ques1
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
#load the data
file = pd.read_csv('WorldUniversityRanking.csv', encoding='latin1')

# %%
#Display first 5 rows
file.head()
# Out:
#   RANK_2025 RANK_2024                              Institution_Name  \
# 0         1         1  Massachusetts Institute of Technology (MIT)
# 1         2         6                       Imperial College London
# 2         3         3                          University of Oxford
# 3         4         4                            Harvard University
# 4         5         2                       University of Cambridge
#
#          Location    Region SIZE FOCUS RES. STATUS  Academic_Reputation_Score  \
# 0   United States  Americas    M    CO   VH      B                      100.0
# 1  United Kingdom    Europe    L    FC   VH      A                       98.5
# 2  United Kingdom    Europe    L    FC   VH      A                      100.0
# 3   United States  Americas    L    FC   VH      B                      100.0
# 4  United Kingdom    Europe    L    FC   VH      A                      100.0
#
#    ... International_Faculty_Rank  International_Students_Score  \
# ...

# %%
#shape of dataset
file.shape
# Out:
# (1503, 28)

# %%
#columns 
col = file.columns
col
# Out:
# Index(['RANK_2025', 'RANK_2024', 'Institution_Name', 'Location', 'Region',
#        'SIZE', 'FOCUS', 'RES.', 'STATUS', 'Academic_Reputation_Score',
#        'Academic_Reputation_Rank', 'Employer_Reputation_Score',
#        'Employer_Reputation_Rank', 'Faculty_Student_Score',
#        'Faculty_Student_Rank', 'Citations_per_Faculty_Score',
#        'Citations_per_Faculty_Rank', 'International_Faculty_Score',
#        'International_Faculty_Rank', 'International_Students_Score',
#        'International_Students_Rank', 'International_Research_Network_Score',
#        'International_Research_Network_Rank', 'Employment_Outcomes_Score',
#        'Employment_Outcomes_Rank', 'Sustainability_Score',
#        'Sustainability_Rank', 'Overall_Score'],
#       dtype='str')

# %%
#dataTypes
file.dtypes
# Out:
# RANK_2025                                   str
# RANK_2024                                   str
# Institution_Name                            str
# Location                                    str
# Region                                      str
# SIZE                                        str
# FOCUS                                       str
# RES.                                        str
# STATUS                                      str
# Academic_Reputation_Score               float64
# Academic_Reputation_Rank                    str
# Employer_Reputation_Score               float64
# Employer_Reputation_Rank                    str
# Faculty_Student_Score                   float64
# Faculty_Student_Rank                        str
# Citations_per_Faculty_Score             float64
# Citations_per_Faculty_Rank                  str
# International_Faculty_Score             float64
# International_Faculty_Rank                  str
# International_Students_Score            float64
# ...

# %%
#Missing Values
file.isna()
# Out:
#       RANK_2025  RANK_2024  Institution_Name  Location  Region   SIZE  FOCUS  \
# 0         False      False             False     False   False  False  False
# 1         False      False             False     False   False  False  False
# 2         False      False             False     False   False  False  False
# 3         False      False             False     False   False  False  False
# 4         False      False             False     False   False  False  False
# ...         ...        ...               ...       ...     ...    ...    ...
# 1498      False      False             False     False   False  False  False
# 1499      False      False             False     False   False  False  False
# 1500      False      False             False     False   False  False  False
# 1501      False      False             False     False   False  False  False
# 1502      False      False             False     False   False  False  False
#
# ...

# %% [markdown]
# Q2. Data Cleaning
# -Convert ranking and score columns into numeric format (if required).
# -Handle missing values:
#    -Drop OR Impute
# -Show before/after comparison.
# -Add a markdown explaining your logic.

# %%
file.dtypes
# Out:
# RANK_2025                                   str
# RANK_2024                                   str
# Institution_Name                            str
# Location                                    str
# Region                                      str
# SIZE                                        str
# FOCUS                                       str
# RES.                                        str
# STATUS                                      str
# Academic_Reputation_Score               float64
# Academic_Reputation_Rank                    str
# Employer_Reputation_Score               float64
# Employer_Reputation_Rank                    str
# Faculty_Student_Score                   float64
# Faculty_Student_Rank                        str
# Citations_per_Faculty_Score             float64
# Citations_per_Faculty_Rank                  str
# International_Faculty_Score             float64
# International_Faculty_Rank                  str
# International_Students_Score            float64
# ...

# %%
file['Faculty_Student_Rank'] = pd.to_numeric(file['Faculty_Student_Rank'],errors='coerce')
file['International_Faculty_Rank'] = pd.to_numeric(file['International_Faculty_Rank'],errors='coerce')
file['Academic_Reputation_Rank'] = pd.to_numeric(file['Academic_Reputation_Rank'],errors='coerce')
file['Employer_Reputation_Rank'] = pd.to_numeric(file['Employer_Reputation_Rank'],errors='coerce')
file['Citations_per_Faculty_Rank'] = pd.to_numeric(file['Citations_per_Faculty_Rank'],errors='coerce')
file['International_Students_Rank'] = pd.to_numeric(file['International_Students_Rank'],errors='coerce')
file['International_Research_Network_Rank'] = pd.to_numeric(file['International_Research_Network_Rank'],errors='coerce')
file['Employment_Outcomes_Rank'] = pd.to_numeric(file['Employment_Outcomes_Rank'],errors='coerce')
file['Sustainability_Rank'] = pd.to_numeric(file['Sustainability_Rank'],errors='coerce')

file['Overall_Score'] = pd.to_numeric(file['Overall_Score'],errors='coerce')
file.dtypes
# Out:
# RANK_2025                                   str
# RANK_2024                                   str
# Institution_Name                            str
# Location                                    str
# Region                                      str
# SIZE                                        str
# FOCUS                                       str
# RES.                                        str
# STATUS                                      str
# Academic_Reputation_Score               float64
# Academic_Reputation_Rank                float64
# Employer_Reputation_Score               float64
# Employer_Reputation_Rank                float64
# Faculty_Student_Score                   float64
# Faculty_Student_Rank                    float64
# Citations_per_Faculty_Score             float64
# Citations_per_Faculty_Rank              float64
# International_Faculty_Score             float64
# International_Faculty_Rank              float64
# International_Students_Score            float64
# ...

# %%
file.dropna(inplace=True)

# %% [markdown]
# Data Cleaning Explanation->
# 1.First, we converted ranking and score columns into numeric format so that we can perform mathematical operations.
# 2.After that, we handled missing values .
# 3.After cleaning, the dataset became more accurate and ready for visualization and analysis.

# %% [markdown]
# Q3. Feature Engineering (Using NumPy)
# Create a new column Score_Category:
#
# Elite → ≥ 90
# High → 75–89
# Medium → 50–74
# Low → < 50
# Use numpy.where() or vectorized operations.

# %%
import numpy as np

file['Overall_Score'] = pd.to_numeric(file['Overall_Score'],errors='coerce')

file['Score_Category'] = np.where(
    file['Overall_Score'] >=90, 'Elite',

    np.where(file['Overall_Score'] >=75, 'High',
             
             np.where(file['Overall_Score'] >=50, 'Medium','Low'))
)
file[['Overall_Score', 'Score_Category']]
# Out:
#      Overall_Score Score_Category
# 1             98.5          Elite
# 2             96.9          Elite
# 3             96.8          Elite
# 6             93.9          Elite
# 9             90.9          Elite
# 10            90.3          Elite
# 11            90.1          Elite
# 23            84.7           High
# 24            84.1           High
# 27            83.2           High
# 28            83.0           High
# 34            82.0           High
# 37            81.0           High
# 38            80.3           High
# 40            80.2           High
# 44            77.8           High
# 48            77.0           High
# 51            76.0           High
# 53            75.4           High
# 61            70.7         Medium
# 63            70.3         Medium
# 68            68.2         Medium
# 73            65.7         Medium
# 74            65.6         Medium
# 77            65.0         Medium
# 78            64.7         Medium
# ...

# %% [markdown]
# # Section2: Exploratory Data Analysis

# %% [markdown]
# Q4. Top Universities Analysis
# Find Top 10 universities by rank.
#
# Plot using:
# matplotlib OR seaborn
# Add proper labels, title, and formatting.
# Write 2–3 insights in markdown.

# %%
top_universities = file.sort_values(by='RANK_2025').head(10)  # sort by 10 and get top 10

#plot
plt.figure()
plt.bar(top_universities['Institution_Name'], top_universities['RANK_2025'])
plt.title('Top 10 Universities in 2025')
plt.xlabel('Institution Name')
plt.ylabel('Rank_2025')
plt.xticks(rotation=45,ha='right')

plt.show()

# %% [markdown]
# insights->
# 1.Universities with smaller rank numbers are the top universities.
# 2.This graph makes it easy to comapre the top 10 universities.

# %% [markdown]
# Q5. Country-wise Dominance
# Count universities per country.
#
# Display Top 10 countries.
# Create an interactive chart using Plotly.
# Add interpretation.

# %%
country_counts = file['Location'].value_counts().head(10)

fig = px.bar(
    x = country_counts.index,
    y=country_counts.values,
    labels={
        'x':'Country',
        'y':'Number of Universities'
    },
    title='Top 10 Countries by Universities'
)
fig.show()

# %% [markdown]
# Interpretaion->
# This graph compares how universities are distributed across differnt countries.

# %% [markdown]
# Q6. Score Distribution
# Plot histogram + KDE using Seaborn.
#
# Analyze distribution:
# Skewed / Normal / Uniform
# Add explanation.

# %%
file.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 53 entries, 1 to 317
# Data columns (total 29 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   RANK_2025                             53 non-null     str
#  1   RANK_2024                             53 non-null     str
#  2   Institution_Name                      53 non-null     str
#  3   Location                              53 non-null     str
#  4   Region                                53 non-null     str
#  5   SIZE                                  53 non-null     str
#  6   FOCUS                                 53 non-null     str
#  7   RES.                                  53 non-null     str
#  8   STATUS                                53 non-null     str
#  9   Academic_Reputation_Score             53 non-null     float64
#  10  Academic_Reputation_Rank              53 non-null     float64
# ...

# %%
sns.histplot(file['Overall_Score'],kde=True)
plt.title('Distribution of Overall Scores')
# Out:
# Text(0.5, 1.0, 'Distribution of Overall Scores')

# %%
#Q7-> Correlation Analysis->
file["Overall_Score"].skew()
# Out:
# np.float64(0.13206810882091058)

# %% [markdown]
# The graph shows how the university scores are spread in the dataset.

# %% [markdown]
# ## Correlation Analysis
# Compute correlation matrix.
# Plot heatmap using seaborn.
# Identify strongest relationships.

# %%
corr_matrix = file.corr(numeric_only=True)
sns.heatmap(corr_matrix)
plt.title('Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %% [markdown]
# Strongest relationship->
# 1.Columns with correlation values closest to +1 have the strongest positive relationships.
# 2.Columns with values -1 or closest have the strongest negative relationaships.
# 3.correaltion with near 0 shows no relationship or weak relationship.

# %% [markdown]
# Q8. Region-wise Performance
# Compute average score per region using pandas.
# Plot using Matplotlib.
# Add interpretation.

# %%
region_scores = file.groupby('Region')['Overall_Score'].mean()
plt.bar(
    region_scores.index,
    region_scores.values
)
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Africa'),
#   Text(1, 0, 'Americas'),
#   Text(2, 0, 'Asia'),
#   Text(3, 0, 'Europe'),
#   Text(4, 0, 'Oceania')])

# %% [markdown]
# Interpretation->
# Regions with taller bars show better overall university performance.

# %% [markdown]
# Q9. Rank vs Score Relationship
# Create scatter plot using Plotly:
# X → Rank
# Y → Score
# Add trendline.

# %%
file["RANK_2025"] = pd.to_numeric(file["RANK_2025"],errors='coerce')
file.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 53 entries, 1 to 317
# Data columns (total 29 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   RANK_2025                             53 non-null     int64
#  1   RANK_2024                             53 non-null     str
#  2   Institution_Name                      53 non-null     str
#  3   Location                              53 non-null     str
#  4   Region                                53 non-null     str
#  5   SIZE                                  53 non-null     str
#  6   FOCUS                                 53 non-null     str
#  7   RES.                                  53 non-null     str
#  8   STATUS                                53 non-null     str
#  9   Academic_Reputation_Score             53 non-null     float64
#  10  Academic_Reputation_Rank              53 non-null     float64
# ...

# %%
px.scatter(file,x='RANK_2025',y='Overall_Score')

# %%
px.scatter(file,x='RANK_2025',y='Overall_Score',trendline='ols')

# %% [markdown]
# Comment on Relationship->
# ->The scatter plot shows a negative relationship between rank and overall score.
# -> As the rank increases, the overall score tends to decrease.

# %% [markdown]
# # Section 3: Analytical Use Cases

# %% [markdown]
# Q10. Top University per Country
# For each country, find the highest-ranked university.
# Display as a DataFrame.

# %%
top_universities = file.loc[file.groupby('Location')['RANK_2025'].idxmin()]
top_universities
# Out:
#      RANK_2025 RANK_2024                                   Institution_Name  \
# 40          40        43                       The University of Queensland
# 136        137       130                               University of Vienna
# 168        169       159                                   Ghent University
# 24          25        21                              University of Toronto
# 38          39        50                                   Fudan University
# 108        109       121                    Technical University of Denmark
# 112        113       109                                   Aalto University
# 23          24        24                                     Université PSL
# 27          28        37                     Technical University of Munich
# 61          62        70                       City University of Hong Kong
# 272        273       292                            University College Cork
# ...

# %% [markdown]
# Q11. Outlier Detection
# Detect outliers using:
# IQR OR Z-score (numpy)
# Visualize using boxplot (seaborn).
# Mention number of outliers found.

# %% [markdown]
# IQR=Q3−Q1
# Lower Limit=Q1−1.5×IQR
# Upper Limit=Q3+1.5×IQR

# %%
Q1 = file['Overall_Score'].quantile(0.25)
Q3 = file['Overall_Score'].quantile(0.75)
IQR = Q3-Q1
lower_limit = Q1 - 1.5*IQR
upper_limit = Q3 + 1.5*IQR

#outliers
outliers = file[
    (file['Overall_Score'] <lower_limit) | (file['Overall_Score'] > upper_limit)
]
#no. of outliers
outliers

#boxplot
sns.boxplot(file,x="Overall_Score")
# Out:
# <Axes: xlabel='Overall_Score'>

# %% [markdown]
# Q12. Score Category Analysis
# Count universities in each Score_Category.
# Plot:
# Pie chart OR Bar chart
# Interpret proportions.

# %%
score=file['Score_Category'].value_counts()

# %%
plt.pie(score,labels=score.index,autopct='%1.1f%%')
plt.title('Pie-chart')
# Out:
# Text(0.5, 1.0, 'Pie-chart')

# %% [markdown]
# Q14. Multi-variable Visualization
# Create Plotly scatter:
# X → Score
# Y → Rank
# Color → Region
# Size → Score
# Derive 2–3 insights.

# %%
px.scatter(file,
           x=file['Overall_Score'],y=file['RANK_2025'],color = 'Region', size='Overall_Score'
           )

# %% [markdown]
# Insights
# Higher score universities usually have better ranks.
# Some regions have more good-performing universities than others.
# Universities with high scores mostly appear at top ranks.
